# %%
from src.papers import FetchPMIDS
pmids=FetchPMIDS('WMT83805')
print(pmids)

# %%
from src.papers import SearchPubmed
query=SearchPubmed('Pseudoalteromonas phage proACA1-A')
query

# %%
37896838

# %%
from src.papers import SearchPubmed
query=SearchPubmed('Polaribacter phage P12002L')
query
# Out:
# ['PMC11019789',
#  'PMC9892861',
#  'PMC8776804',
#  'PMC7198788',
#  'PMC6287040',
#  'PMC5332604',
#  'PMC4615864',
#  '26500718']

# %%
from main import SummaryTMP
result=SummaryTMP('YP_010108907', 'gemma4:e4b')
result
# Out:
# ClassifyHostMetadata: host='Flavobacterium sp. BAL314' taxonomic_level='species' host_reasoning="The metadata explicitly contains the key 'host' with the value 'Flavobacterium sp. BAL314'." host_found=True
#
#
# download: s3://pmc-oa-opendata/PMC7077304.1/PMC7077304.1.txt to data/accessions/YP_010108907/library/host_lit/PMC7077304.1.txt
# download: s3://pmc-oa-opendata/PMC13151707.1/PMC13151707.1.txt to data/accessions/YP_010108907/library/host_lit/PMC13151707.1.txt
# {'model': 'gemma4:e4b',
#  'accession': 'YP_010108907',
#  'phage': 'Flavobacterium phage vB_FspP_elemoA_7-9A',
#  'metadata': {'uid': '2047454209',
#   'accession': 'YP_010108907',
#   'title': 'structural protein [Flavobacterium phage vB_FspP_elemoA_7-9A]',
#   'organism': 'Flavobacterium phage vB_FspP_elemoA_7-9A',
#   'taxonId': 2743781,
#   'sequence_length': 3694,
#   'create_date': '2021/06/02',
#   'update_date': '2023/01/11',
#   'dbsource': 'refseq',
#   'extra': 'gi|2047454209|ref|YP_010108907.1|',
# ...

# %%
# Out:
# ['PMC111', 'PMC222', 'PMC333']
