# %%
###########################################################################################################################################################
# QWEN3.5
###########################################################################################################################################################


# IDENTIFYING THE THERMAL RANGE OF PHAGE FROM METADATA
from no_context import *
from tools import *
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

df=pd.read_csv('data/example/example_data.csv')
accessions=df['Accession']

with open(f'results/no_context/qwen3.5/thermal_metadata_classification.txt','w') as f:
    f.write(f'Classifying thermal range of bacteriophage using only the metadata\n')
    f.write(f'Forced output, must return a classification\n')

with open(f'results/no_context/qwen3.5/thermal_metadata_classification.csv','w') as f:
    f.write('accession,thermal_range,duration(m)\n')
full_start=time.time()
for accession in accessions:
    with open(f'results/no_context/qwen3.5/thermal_metadata_classification.txt','a') as f:
        f.write(f'============={accession}=============\n')
    metadata=FetchNcbiMetadata(accession)

    state = {
            'paper_text': None,
            'source_path': None,
            'model': 'qwen3.5',
            'metadata': metadata,
            'phage': metadata.get('organism', 'unknown'),
            'host_species': None,
            'reasoning': None,
            'confidence': None,
            'thermal_range': None,
            'temperature': None,
            'thermal_reasoning': None,
            'thermal_confidence': None,
        }
    acc_start=time.time()
    out=IdentifyThermalRangeNoContext(state)
    acc_end=time.time()
    acc_duration=(round(acc_end-acc_start,2)/60)
    print(f'{accession}: {out.get("thermal_range")}')


    with open(f'results/no_context/qwen3.5/thermal_metadata_classification.csv','a') as f:
        f.write(f'{accession},{out.get("thermal_range", "unknown")},{acc_duration}\n')

    with open(f'results/no_context/qwen3.5/thermal_metadata_classification.txt','a') as f:
        f.write(f'Thermal Classification: {out.get("thermal_range", "unknown")}\n')
        f.write(f'Duration: {acc_duration}\n')

full_end=time.time()
full_duration=(round(full_end-full_start,2)/60)
with open(f'results/no_context/qwen3.5/thermal_metadata_classification.txt','a') as f:
    f.write(f'\n\nFull Duration: {full_duration} minutes\n')

pred_df=pd.read_csv('results/no_context/qwen3.5/thermal_metadata_classification.csv')

# Create confusion matrix
actual=df['Thermal Range']
pred=pred_df['thermal_range']
plot=ConfusionMatrix(actual, pred)
plot.plot(cmap='Blues')
plt.savefig('results/no_context/qwen3.5/confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()


# Get the classification report
classification_report=classification_report(actual, pred)

with open('results/no_context/qwen3.5/classification_report.txt', 'w') as f:
    f.write(classification_report)
# Out:
# LLM OUTPUT: thermal_range='mesophile'
# ADI87650: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WXH46553: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WRQ14408: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# XYW65533: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# SNQ28030: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049775: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049787: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956829: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# AAC18470: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_046847: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040628: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040587: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042001: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042005: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_041967: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049666: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010085862: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009168084: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956832: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956835: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# A7XXB7: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# QAY18187: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285867: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835731: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_874174: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468074: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468079: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468077: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468072: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285862: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# BFP65619: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285822: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# ABI36835: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835728: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835725: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001210360: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_015542: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468067: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509140: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509134: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# XJP07760: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83805: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790355: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489335: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_009209738: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83702: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83700: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790354: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790351: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790347: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790336: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008887: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008883: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008872: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489330: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489329: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489332: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_112541: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108907: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108902: mesophile

# %%
###########################################################################################################################################################
# GEMMA4
###########################################################################################################################################################


# IDENTIFYING THE THERMAL RANGE OF PHAGE FROM METADATA
from no_context import *
from tools import *
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

df=pd.read_csv('data/example/example_data.csv')
accessions=df['Accession']

with open(f'results/no_context/gemma4/thermal_metadata_classification.txt','w') as f:
    f.write(f'Classifying thermal range of bacteriophage using only the metadata\n')
    f.write(f'Forced output, must return a classification\n')

with open(f'results/no_context/gemma4/thermal_metadata_classification.csv','w') as f:
    f.write('accession,thermal_range,duration(m)\n')
full_start=time.time()
for accession in accessions:
    with open(f'results/no_context/gemma4/thermal_metadata_classification.txt','a') as f:
        f.write(f'============={accession}=============\n')
    metadata=FetchNcbiMetadata(accession)

    state = {
            'paper_text': None,
            'source_path': None,
            'model': 'gemma4:e4b',
            'metadata': metadata,
            'phage': metadata.get('organism', 'unknown'),
            'host_species': None,
            'reasoning': None,
            'confidence': None,
            'thermal_range': None,
            'temperature': None,
            'thermal_reasoning': None,
            'thermal_confidence': None,
        }
    acc_start=time.time()
    out=IdentifyThermalRangeNoContext(state)
    acc_end=time.time()
    acc_duration=(round(acc_end-acc_start,2)/60)
    print(f'{accession}: {out.get("thermal_range")}')


    with open(f'results/no_context/gemma4/thermal_metadata_classification.csv','a') as f:
        f.write(f'{accession},{out.get("thermal_range", "unknown")},{acc_duration}\n')

    with open(f'results/no_context/gemma4/thermal_metadata_classification.txt','a') as f:
        f.write(f'Thermal Classification: {out.get("thermal_range", "unknown")}\n')
        f.write(f'Duration: {acc_duration}\n')

full_end=time.time()
full_duration=(round(full_end-full_start,2)/60)
with open(f'results/no_context/gemma4/thermal_metadata_classification.txt','a') as f:
    f.write(f'\n\nFull Duration: {full_duration} minutes\n')


pred_df=pd.read_csv('results/no_context/gemma4/thermal_metadata_classification.csv')

# Create confusion matrix
actual=df['Thermal Range']
pred=pred_df['thermal_range']
plot=ConfusionMatrix(actual, pred)
plot.plot(cmap='Blues')
plt.savefig('results/no_context/gemma4/confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()


# Get the classification report
classification_report=classification_report(actual, pred)

with open('results/no_context/gemma4/classification_report.txt', 'w') as f:
    f.write(classification_report)
# Out:
# LLM OUTPUT: thermal_range='mesophile'
# ADI87650: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WXH46553: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WRQ14408: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# XYW65533: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# SNQ28030: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049775: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049787: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956829: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# AAC18470: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_046847: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040628: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040587: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042001: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042005: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_041967: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049666: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010085862: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009168084: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956832: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956835: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# A7XXB7: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# QAY18187: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285867: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835731: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_874174: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468074: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468079: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468077: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468072: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285862: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# BFP65619: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285822: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# ABI36835: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835728: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# NP_835725: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001210360: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_015542: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468067: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509140: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509134: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# XJP07760: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83805: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790355: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489335: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009209738: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83702: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83700: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790354: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790351: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790347: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790336: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008887: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008883: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008872: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489330: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489329: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_006489332: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_112541: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108907: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108902: mesophile

# %%
###########################################################################################################################################################
# GRANITE4.1
###########################################################################################################################################################


# IDENTIFYING THE THERMAL RANGE OF PHAGE FROM METADATA
from no_context import *
from tools import *
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


df=pd.read_csv('data/example/example_data.csv')
accessions=df['Accession']

with open(f'results/no_context/granite4.1/thermal_metadata_classification.txt','w') as f:
    f.write(f'Classifying thermal range of bacteriophage using only the metadata\n')
    f.write(f'Forced output, must return a classification\n')

with open(f'results/no_context/granite4.1/thermal_metadata_classification.csv','w') as f:
    f.write('accession,thermal_range,duration(m)\n')
full_start=time.time()
for accession in accessions:
    with open(f'results/no_context/granite4.1/thermal_metadata_classification.txt','a') as f:
        f.write(f'============={accession}=============\n')
    metadata=FetchNcbiMetadata(accession)

    state = {
            'paper_text': None,
            'source_path': None,
            'model': 'ibm/granite4.1:8b',
            'metadata': metadata,
            'phage': metadata.get('organism', 'unknown'),
            'host_species': None,
            'reasoning': None,
            'confidence': None,
            'thermal_range': None,
            'temperature': None,
            'thermal_reasoning': None,
            'thermal_confidence': None,
        }
    acc_start=time.time()
    out=IdentifyThermalRangeNoContext(state)
    acc_end=time.time()
    acc_duration=(round(acc_end-acc_start,2)/60)
    print(f'{accession}: {out.get("thermal_range", "unknown")}')


    with open(f'results/no_context/granite4.1/thermal_metadata_classification.csv','a') as f:
        f.write(f'{accession},{out.get("thermal_range", "unknown")},{acc_duration}\n')

    with open(f'results/no_context/granite4.1/thermal_metadata_classification.txt','a') as f:
        f.write(f'Thermal Classification: {out.get("thermal_range", "unknown")}\n')
        f.write(f'Duration: {acc_duration}\n')

full_end=time.time()
full_duration=(round(full_end-full_start,2)/60)
with open(f'results/no_context/granite4.1/thermal_metadata_classification.txt','a') as f:
    f.write(f'\n\nFull Duration: {full_duration} minutes\n')

pred_df=pd.read_csv('results/no_context/granite4.1/thermal_metadata_classification.csv')

# Create confusion matrix
actual=df['Thermal Range']
pred=pred_df['thermal_range']
plot=ConfusionMatrix(actual, pred)
plot.plot(cmap='Blues')
plt.savefig('results/no_context/granite4.1/confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()


# Get the classification report
classification_report=classification_report(actual, pred)

with open('results/no_context/granite4.1/classification_report.txt', 'w') as f:
    f.write(classification_report)
# Out:
# LLM OUTPUT: thermal_range='mesophile'
# ADI87650: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WXH46553: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# WRQ14408: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# XYW65533: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# SNQ28030: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049775: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049787: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956829: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# AAC18470: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_046847: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040628: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_040587: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042001: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_042005: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_041967: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_049666: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010085862: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009168084: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956832: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_001956835: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# A7XXB7: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# QAY18187: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285867: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_835731: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_874174: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468074: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468079: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468077: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468072: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285862: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# BFP65619: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001285822: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# ABI36835: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_835728: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# NP_835725: mesophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001210360: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_015542: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_001468067: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509140: thermophile
# LLM OUTPUT: thermal_range='thermophile'
# YP_009509134: thermophile
# LLM OUTPUT: thermal_range='mesophile'
# XJP07760: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83805: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790355: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_006489335: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009209738: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83702: psychrophile
# LLM OUTPUT: thermal_range='psychrophile'
# WMT83700: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790354: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790351: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790347: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009790336: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008887: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008883: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_009008872: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_006489330: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_006489329: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_006489332: mesophile
# LLM OUTPUT: thermal_range='psychrophile'
# YP_112541: psychrophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108907: mesophile
# LLM OUTPUT: thermal_range='mesophile'
# YP_010108902: mesophile
