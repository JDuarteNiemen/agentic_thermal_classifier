# %%
import pandas as pd
df=pd.read_csv('benchmarks/benchmark_results.csv')

# %%
df
# Out:
#          version  precision  recall    f1  support  duration (minutes)  \
# 0             v2        NaN     NaN   NaN       15             1215.00
# 1             v3       0.93    0.94  0.93       15               54.20
# 2             v4       0.65    0.71  0.66       15               38.38
# 3     v5-qwen3.5       0.71    0.65  0.66       15               39.64
# 4      v5-gemma4       0.65    0.59  0.58       60               31.98
# 5  v5-granite4.1       0.82    0.73  0.70       60               39.85
# 6             v6       0.66    0.59  0.58       60               51.95
# 7             v7       0.66    0.60  0.59       60              142.82
#
#    test_data_size       model  reasoning literature classifications  \
# 0              15         NaN       True                        NaN
# 1              15     qwen3.5      False                        NaN
# 2              15     qwen3.5      False                        NaN
# ...
