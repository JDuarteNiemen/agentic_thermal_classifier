# %%
# IDENTIFYING THERMAL RANGE USING ONLY THE NAME OF THE PHAGE
from no_context import *
from tools import *
import pandas as pd
import time

df=pd.read_csv('data/example/example_data.csv')
accessions=df['Accession']

with open(f'results/no_context/thermal_name_classification.txt','w') as f:
    f.write(f'Classifying thermal range of bacteriophage using only the name of the phage\n')
    f.write(f'Forced output, must return a classification\n')

with open(f'results/no_context/thermal_name_classification.csv','w') as f:
    f.write('accession,thermal_range,duration(m)\n')
full_start=time.time()
for accession in accessions:
    with open(f'results/no_context/thermal_name_classification.txt','a') as f:
        f.write(f'============={accession}=============\n')
    metadata=FetchNcbiMetadata(accession)


    state = {
            'paper_text': None,
            'source_path': None,
            'model': 'qwen3.5',
            'metadata': None,
            'phage': metadata.get('organism', 'unknown'),
            'host_species': None,
            'reasoning': None,
            'confidence': None,
            'thermal_range': None,
            'temperature': None,
            'thermal_reasoning': None,
            'thermal_confidence': None,
        }
    acc_start=time.time()
    out=IdentifyThermalRangeName(state)
    acc_end=time.time()
    acc_duration=(acc_end-acc_start)/60
    print(f'{accession}: {out.get("thermal_range")}')


    with open(f'results/no_context/thermal_name_classification.csv','a') as f:
        f.write(f'{accession},{out.get("thermal_range", "unknown")},{round(acc_duration,2)}\n')

    with open(f'results/no_context/thermal_name_classification.txt','a') as f:
        f.write(f'Thermal Classification: {out.get("thermal_range", "unknown")}\n')
        f.write(f'Duration: {round(acc_duration,2)}\n')

full_end=time.time()
full_duration=(full_end-full_start)/60
with open(f'results/no_context/thermal_name_classification.txt','a') as f:
    f.write(f'\n\nFull Duration: {round(full_duration,2)} minutes\n')
# Out:
# {'uid': '298571302', 'accession': 'ADI87650', 'title': 'major head protein, partial [Tequatrovirus T4]', 'organism': 'Tequatrovirus T4', 'taxonId': 10665, 'sequence_length': 141, 'create_date': '2010/06/23', 'update_date': '2016/07/25', 'dbsource': 'insd', 'extra': 'gi|298571302|gb|ADI87650.1|', 'host': 'Enterobacteriales', 'old_name': 'Escherichia virus T4', 'map': 'between gp22 and SegD', 'clone': 's10-10', 'country': 'China: Donghu Lake, Wuhan'}
# LLM OUTPUT: content='{\n  "thermal_range": "mesophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:19:56.023767Z', 'done': True, 'done_reason': 'stop', 'total_duration': 22768040125, 'load_duration': 82164375, 'prompt_eval_count': 133, 'prompt_eval_duration': 493544000, 'eval_count': 592, 'eval_duration': 21973811379, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd99c-01fe-7ea1-a4eb-cf9a707d294d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 133, 'output_tokens': 592, 'total_tokens': 725}
# ADI87650: mesophile
# {'uid': '2701066911', 'accession': 'WXH46553', 'title': 'terminase large subunit [Teseptimavirus T7]', 'organism': 'Teseptimavirus T7', 'taxonId': 1985738, 'sequence_length': 586, 'create_date': '2024/03/25', 'update_date': '2024/03/25', 'dbsource': 'insd', 'extra': 'gi|2701066911|gb|WXH46553.1|', 'host': 'Escherichia coli B', 'clone': 'recombinant T7_mCg1o', 'country': 'USA', 'collection_date': '01-Jan-2024'}
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:22:31.941804Z', 'done': True, 'done_reason': 'length', 'total_duration': 155615083459, 'load_duration': 99845334, 'prompt_eval_count': 134, 'prompt_eval_duration': 466526542, 'eval_count': 4096, 'eval_duration': 153554842263, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd99c-5c24-7c50-a66d-d3e1fee6a870-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 134, 'output_tokens': 4096, 'total_tokens': 4230}
# WXH46553: None
# {'uid': '2647417185', 'accession': 'WRQ14408', 'title': 'endolysin [Escherichia phage Lambda]', 'organism': 'Escherichia phage Lambda', 'taxonId': 2681611, 'sequence_length': 158, 'create_date': '2024/01/16', 'update_date': '2024/01/16', 'dbsource': 'insd', 'extra': 'gi|2647417185|gb|WRQ14408.1|', 'isolate': 'P9/2022/SA', 'host': 'Escherichia sp.', 'country': 'South Africa', 'isolation_source': 'Cloacal swabs from Gallus gallus domesticus', 'collection_date': '06-Dec-2022'}
# LLM OUTPUT: content='{\n  "thermal_range": "mesophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:22:52.402057Z', 'done': True, 'done_reason': 'stop', 'total_duration': 19635791834, 'load_duration': 103911334, 'prompt_eval_count': 134, 'prompt_eval_duration': 475169625, 'eval_count': 507, 'eval_duration': 18872949586, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd99e-bf3c-7672-9726-0746c4609977-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 134, 'output_tokens': 507, 'total_tokens': 641}
# WRQ14408: mesophile
# {'uid': '3042835930', 'accession': 'XYW65533', 'title': 'DNA helicase [Escherichia phage T2]', 'organism': 'Escherichia phage T2', 'taxonId': 2060721, 'sequence_length': 503, 'create_date': '2025/08/18', 'update_date': '2025/08/18', 'dbsource': 'insd', 'extra': 'gi|3042835930|gb|XYW65533.1|', 'host': 'Escherichia coli K-12 BW25113', 'note': 'ymfE mutant', 'country': 'USA', 'collection_date': 'Jun-2025'}
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:25:27.778381Z', 'done': True, 'done_reason': 'length', 'total_duration': 154932603917, 'load_duration': 101844833, 'prompt_eval_count': 135, 'prompt_eval_duration': 469297750, 'eval_count': 4096, 'eval_duration': 152845183590, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd99f-0dab-7773-902d-0858aaa05ef0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 135, 'output_tokens': 4096, 'total_tokens': 4231}
# XYW65533: None
# {'uid': '1229202884', 'accession': 'SNQ28030', 'title': 'RNA replicase, beta subunit [Emesvirus zinderi]', 'organism': 'Emesvirus zinderi', 'taxonId': 329852, 'sequence_length': 545, 'create_date': '2017/08/08', 'update_date': '2018/06/15', 'dbsource': 'insd', 'extra': 'gi|1229202884|emb|SNQ28030.1|', 'isolate': 'EnteroPH/GER/L00928-K20_14-03/2014', 'old_name': 'Escherichia virus MS2', 'note': 'monopartite'}
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:28:00.914505Z', 'done': True, 'done_reason': 'length', 'total_duration': 152596661667, 'load_duration': 105776292, 'prompt_eval_count': 133, 'prompt_eval_duration': 467870083, 'eval_count': 4096, 'eval_duration': 150460655603, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9a1-6cfc-70e0-b22e-c01c0cf6dc07-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 133, 'output_tokens': 4096, 'total_tokens': 4229}
# SNQ28030: None
# {'uid': '1679373715', 'accession': 'A7XXB7', 'title': 'RecName: Full=Terminase, large subunit; AltName: Full=DNA-packaging protein; AltName: Full=Gene product 85; Short=gp85; Includes: RecName: Full=ATPase; Includes: RecName: Full=Endonuclease', 'organism': 'Thermus phage P23-45', 'taxonId': 2914006, 'sequence_length': 485, 'create_date': '2019/05/08', 'update_date': '2026/01/28', 'dbsource': 'swiss_prot', 'extra': 'gi|1679373715|sp|A7XXB7.1|TERL_BP234', 'host': 'Thermus thermophilus'}
# LLM OUTPUT: content='{\n  "thermal_range": "thermophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:28:48.435292Z', 'done': True, 'done_reason': 'stop', 'total_duration': 46722869750, 'load_duration': 86653208, 'prompt_eval_count': 137, 'prompt_eval_duration': 486602125, 'eval_count': 1218, 'eval_duration': 45716345346, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9a3-c42f-7f31-acc8-9397d1277975-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 137, 'output_tokens': 1218, 'total_tokens': 1355}
# A7XXB7: thermophile
# {'uid': '1565796668', 'accession': 'QAY18187', 'title': 'metal-dependent hydrolase [Thermus phage TSP4]', 'organism': 'Thermus phage TSP4', 'taxonId': 1298530, 'sequence_length': 287, 'create_date': '2019/02/06', 'update_date': '2019/02/06', 'dbsource': 'insd', 'extra': 'gi|1565796668|gb|QAY18187.1|', 'host': 'Thermus sp. TC4', 'country': 'China', 'collection_date': '01-Jan-2008'}
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:30:38.942333Z', 'done': True, 'done_reason': 'stop', 'total_duration': 110056239209, 'load_duration': 101872750, 'prompt_eval_count': 134, 'prompt_eval_duration': 486686416, 'eval_count': 2919, 'eval_duration': 108406543253, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9a4-7c74-7cb2-831c-1268359a4854-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 134, 'output_tokens': 2919, 'total_tokens': 3053}
# QAY18187: thermophile
# {'uid': '148747787', 'accession': 'YP_001285867', 'title': 'ATPase [Geobacillus virus E2]', 'organism': 'Geobacillus virus E2', 'taxonId': 447909, 'sequence_length': 49, 'create_date': '2007/06/11', 'update_date': '2023/01/08', 'dbsource': 'refseq', 'extra': 'gi|148747787|ref|YP_001285867.1|', 'host': 'Geobacillus', 'country': 'China', 'isolation_source': 'deep-sea hydrothermal field'}
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:31:06.924735Z', 'done': True, 'done_reason': 'stop', 'total_duration': 27542084375, 'load_duration': 87789125, 'prompt_eval_count': 134, 'prompt_eval_duration': 466498500, 'eval_count': 728, 'eval_duration': 26718918860, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9a6-2c15-79b2-acc5-c34a2f9d188b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 134, 'output_tokens': 728, 'total_tokens': 862}
# YP_001285867: thermophile
# {'uid': '30044134', 'accession': 'NP_835731', 'title': 'RNA polymerase sigma factor [Rhodothermus phage RM378]', 'organism': 'Rhodothermus phage RM378', 'taxonId': 148943, 'sequence_length': 199, 'create_date': '2003/04/22', 'update_date': '2023/01/08', 'dbsource': 'refseq', 'extra': 'gi|30044134|gnl|REF_NCBI_MICRO|phiN315_144|ref|NP_835731.1|', 'host': 'Rhodothermus marinus', 'old_name': 'Bacteriophage RM 378'}
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:38:43.890424Z', 'done': True, 'done_reason': 'stop', 'total_duration': 128274233958, 'load_duration': 102764042, 'prompt_eval_count': 137, 'prompt_eval_duration': 476174916, 'eval_count': 1203, 'eval_duration': 126227452432, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9a6-98dc-7260-951f-d219f61ea20e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 137, 'output_tokens': 1203, 'total_tokens': 1340}
# NP_835731: thermophile
# {'uid': '118197781', 'accession': 'YP_874174', 'title': 'Fe-S oxidoreductase [Thermus phage phiYS40]', 'organism': 'Thermus phage phiYS40', 'taxonId': 407392, 'sequence_length': 355, 'create_date': '2006/11/21', 'update_date': '2023/01/08', 'dbsource': 'refseq', 'extra': 'gi|118197781|ref|YP_874174.1|', 'old_name': 'Thermus thermophilus phage YS40'}
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:39:18.753188Z', 'done': True, 'done_reason': 'stop', 'total_duration': 34405500542, 'load_duration': 112629417, 'prompt_eval_count': 135, 'prompt_eval_duration': 468298500, 'eval_count': 895, 'eval_duration': 33514360835, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9ad-9279-7dc2-bd00-a0ac638f2acc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 135, 'output_tokens': 895, 'total_tokens': 1030}
# YP_874174: thermophile
# {'uid': '2843361417', 'accession': 'XJP07760', 'title': 'terminase large subunit [Pseudoalteromonas phage vB_Psp_PY6]', 'organism': 'Pseudoalteromonas phage vB_Psp_PY6', 'taxonId': 3374930, 'sequence_length': 660, 'create_date': '2025/05/15', 'update_date': '2025/05/15', 'dbsource': 'insd', 'extra': 'gi|2843361417|gb|XJP07760.1|', 'host': 'Pseudoalteromonas sp. YM19', 'isolation_source': 'seawater', 'collection_date': '2023'}
# LLM OUTPUT: content='{\n  "thermal_range": "mesophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:40:56.8687Z', 'done': True, 'done_reason': 'stop', 'total_duration': 97638720958, 'load_duration': 106067375, 'prompt_eval_count': 140, 'prompt_eval_duration': 472224583, 'eval_count': 2565, 'eval_duration': 96125381469, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9ae-1abb-7d00-888b-a13e51a5b1d0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 140, 'output_tokens': 2565, 'total_tokens': 2705}
# XJP07760: mesophile
# {'uid': '2574021459', 'accession': 'WMT83805', 'title': 'integrase [Pseudoalteromonas phage proACA1-A]', 'organism': 'Pseudoalteromonas phage proACA1-A', 'taxonId': 3073886, 'sequence_length': 357, 'create_date': '2023/09/11', 'update_date': '2023/09/11', 'dbsource': 'insd', 'extra': 'gi|2574021459|gb|WMT83805.1|', 'host': 'Pseudoalteromonas elyakovii HL-AS1', 'isolation_source': 'arctic sediment', 'lat_lon': '73.640000 N 166.510000 W'}
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:42:19.222661Z', 'done': True, 'done_reason': 'stop', 'total_duration': 81324707541, 'load_duration': 102979666, 'prompt_eval_count': 138, 'prompt_eval_duration': 480150375, 'eval_count': 2147, 'eval_duration': 79952263548, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9af-9c27-7f02-8eac-4c9bd2ce1244-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 138, 'output_tokens': 2147, 'total_tokens': 2285}
# WMT83805: mesophile
# {'uid': '1842002771', 'accession': 'YP_009790355', 'title': 'tail fiber protein [Shewanella phage SppYZU05]', 'organism': 'Shewanella phage SppYZU05', 'taxonId': 1970795, 'sequence_length': 746, 'create_date': '2020/05/15', 'update_date': '2023/01/09', 'dbsource': 'refseq', 'extra': 'gi|1842002771|ref|YP_009790355.1|', 'lab_host': 'Shewanella putrefaciens', 'isolation_source': 'sewage'}
# LLM OUTPUT: content='{\n  "thermal_range": "mesophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:44:32.573615Z', 'done': True, 'done_reason': 'stop', 'total_duration': 132898071250, 'load_duration': 85974209, 'prompt_eval_count': 138, 'prompt_eval_duration': 468574416, 'eval_count': 3448, 'eval_duration': 131106899921, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9b0-db9a-71c0-813e-eb8c672da39b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 138, 'output_tokens': 3448, 'total_tokens': 3586}
# YP_009790355: mesophile
# {'uid': '392973378', 'accession': 'YP_006489335', 'title': 'hypothetical protein COPG_00149, partial [Colwellia phage 9A]', 'organism': 'Colwellia phage 9A', 'taxonId': 765765, 'sequence_length': 99, 'create_date': '2012/06/27', 'update_date': '2023/01/08', 'dbsource': 'refseq', 'extra': 'gi|392973378|gnl|REF_CAMERA-phage|COPG_00149T0|ref|YP_006489335.1|', 'strain': '9A', 'lab_host': 'Colwellia psychrerythaea strain 34H', 'collection_date': '10-Dec-2002'}
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:47:07.478357Z', 'done': True, 'done_reason': 'length', 'total_duration': 154372195792, 'load_duration': 101310917, 'prompt_eval_count': 135, 'prompt_eval_duration': 473913125, 'eval_count': 4096, 'eval_duration': 152261784612, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9b2-e4d0-7870-889d-7368abbb3304-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 135, 'output_tokens': 4096, 'total_tokens': 4231}
# YP_006489335: None
# {'uid': '971756086', 'accession': 'YP_009209738', 'title': 'hypothetical protein AVT43_gp78 [Polaribacter phage P12002L]', 'organism': 'Polaribacter phage P12002L', 'taxonId': 1647386, 'sequence_length': 109, 'create_date': '2016/01/05', 'update_date': '2023/01/08', 'dbsource': 'refseq', 'extra': 'gi|971756086|gnl|REF_P12002L|P12002L_0078|ref|YP_009209738.1|', 'old_name': 'Polaribacter bacteriophage P12002L', 'country': 'South Korea', 'isolation_source': 'seawater'}
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:49:42.750001Z', 'done': True, 'done_reason': 'length', 'total_duration': 154726104833, 'load_duration': 86157042, 'prompt_eval_count': 139, 'prompt_eval_duration': 469528458, 'eval_count': 4096, 'eval_duration': 152675121611, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd9b5-41f6-7621-9122-78e5e1a9c28c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 139, 'output_tokens': 4096, 'total_tokens': 4235}
# YP_009209738: None

# %%
# IDENTIFYING THE THERMAL RANGE OF PHAGE FROM METADATA

from no_context import *
from tools import *
import pandas as pd
import time

df=pd.read_csv('data/example/example_data.csv')
accessions=df['Accession']

with open(f'results/no_context/thermal_metadata_classification.txt','w') as f:
    f.write(f'Classifying thermal range of bacteriophage using only the metadata\n')
    f.write(f'Forced output, must return a classification\n')

with open(f'results/no_context/thermal_metadata_classification.csv','w') as f:
    f.write('accession,thermal_range,duration(m)\n')
full_start=time.time()
for accession in accessions:
    with open(f'results/no_context/thermal_metadata_classification.txt','a') as f:
        f.write(f'============={accession}=============\n')
    metadata=FetchNcbiMetadata(accession)

    state = {
            'paper_text': None,
            'source_path': None,
            'model': 'qwen3.5',
            'metadata': metadata,
            'phage': metadata.get('organism', 'unknown'),
            'host_species': None,
            'reasoning': None,
            'confidence': None,
            'thermal_range': None,
            'temperature': None,
            'thermal_reasoning': None,
            'thermal_confidence': None,
        }
    acc_start=time.time()
    out=IdentifyThermalRangeNoContext(state)
    acc_end=time.time()
    acc_duration=(round(acc_end-acc_start,2)/60)
    print(f'{accession}: {out.get("thermal_range")}')


    with open(f'results/no_context/thermal_metadata_classification.csv','a') as f:
        f.write(f'{accession},{out.get("thermal_range", "unknown")},{acc_duration}\n')

    with open(f'results/no_context/thermal_metadata_classification.txt','a') as f:
        f.write(f'Thermal Classification: {out.get("thermal_range", "unknown")}\n')
        f.write(f'Duration: {acc_duration}\n')

full_end=time.time()
full_duration=(round(full_end-full_start,2)/60)
with open(f'results/no_context/thermal_metadata_classification.txt','a') as f:
    f.write(f'\n\nFull Duration: {full_duration} minutes\n')
# Out:
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:49:04.679259Z', 'done': True, 'done_reason': 'stop', 'total_duration': 47844684041, 'load_duration': 86400875, 'prompt_eval_count': 336, 'prompt_eval_duration': 999570500, 'eval_count': 1257, 'eval_duration': 46322764281, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd97f-6041-7173-b5a8-16475e90ac38-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 336, 'output_tokens': 1257, 'total_tokens': 1593}
# ADI87650: mesophile
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:51:41.251622Z', 'done': True, 'done_reason': 'length', 'total_duration': 156238483666, 'load_duration': 102775208, 'prompt_eval_count': 333, 'prompt_eval_duration': 989636791, 'eval_count': 4096, 'eval_duration': 153708817243, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd980-1c73-7030-9f71-fa7d916b83f3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 333, 'output_tokens': 4096, 'total_tokens': 4429}
# WXH46553: None
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:52:39.931873Z', 'done': True, 'done_reason': 'stop', 'total_duration': 58393919916, 'load_duration': 87665416, 'prompt_eval_count': 350, 'prompt_eval_duration': 995526458, 'eval_count': 1517, 'eval_duration': 56788884280, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd982-7fe0-7b60-bc45-6e2e3fe88490-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 350, 'output_tokens': 1517, 'total_tokens': 1867}
# WRQ14408: mesophile
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:53:31.525456Z', 'done': True, 'done_reason': 'stop', 'total_duration': 51261619542, 'load_duration': 101598375, 'prompt_eval_count': 335, 'prompt_eval_duration': 995124584, 'eval_count': 1331, 'eval_duration': 49718910017, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd983-6546-7f92-a57b-226571938b19-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 335, 'output_tokens': 1331, 'total_tokens': 1666}
# XYW65533: mesophile
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:54:31.13025Z', 'done': True, 'done_reason': 'stop', 'total_duration': 59087754500, 'load_duration': 91072750, 'prompt_eval_count': 338, 'prompt_eval_duration': 991609000, 'eval_count': 1530, 'eval_duration': 57468471287, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd984-2f89-7b72-90bd-9c5793bb7e9b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 338, 'output_tokens': 1530, 'total_tokens': 1868}
# SNQ28030: mesophile
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:55:13.873212Z', 'done': True, 'done_reason': 'stop', 'total_duration': 42093307250, 'load_duration': 104282834, 'prompt_eval_count': 357, 'prompt_eval_duration': 1075788041, 'eval_count': 1092, 'eval_duration': 40528950137, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd985-18e1-7143-a881-b3413eedaba3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 357, 'output_tokens': 1092, 'total_tokens': 1449}
# A7XXB7: thermophile
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:56:26.007074Z', 'done': True, 'done_reason': 'stop', 'total_duration': 71223193541, 'load_duration': 100157916, 'prompt_eval_count': 321, 'prompt_eval_duration': 994899916, 'eval_count': 1878, 'eval_duration': 69459304541, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd985-c0dd-7122-a33e-974aa4d285d9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 321, 'output_tokens': 1878, 'total_tokens': 2199}
# QAY18187: thermophile
# LLM OUTPUT: content='{\n  "thermal_range": "thermophile"\n}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:56:50.273969Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23966223167, 'load_duration': 100281750, 'prompt_eval_count': 317, 'prompt_eval_duration': 894754417, 'eval_count': 609, 'eval_duration': 22768403430, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd986-d842-7ee2-ab8f-48390e40691f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 317, 'output_tokens': 609, 'total_tokens': 926}
# YP_001285867: thermophile
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:57:56.080468Z', 'done': True, 'done_reason': 'stop', 'total_duration': 64656793125, 'load_duration': 102236042, 'prompt_eval_count': 338, 'prompt_eval_duration': 1002895375, 'eval_count': 1687, 'eval_duration': 62986479306, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd987-3a5d-7340-8b0f-405c1d64974a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 338, 'output_tokens': 1687, 'total_tokens': 2025}
# NP_835731: thermophile
# LLM OUTPUT: content='{"thermal_range": "thermophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T13:58:43.766375Z', 'done': True, 'done_reason': 'stop', 'total_duration': 47384163541, 'load_duration': 102567416, 'prompt_eval_count': 310, 'prompt_eval_duration': 887126583, 'eval_count': 1228, 'eval_duration': 45988942285, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd988-381c-7f12-8869-5e8a3374e413-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 310, 'output_tokens': 1228, 'total_tokens': 1538}
# YP_874174: thermophile
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:00:16.107306Z', 'done': True, 'done_reason': 'stop', 'total_duration': 92041162125, 'load_duration': 102041250, 'prompt_eval_count': 340, 'prompt_eval_duration': 997165583, 'eval_count': 2431, 'eval_duration': 90053444940, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd988-f260-7211-98ae-40298dae0a05-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 340, 'output_tokens': 2431, 'total_tokens': 2771}
# XJP07760: mesophile
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:02:49.694988Z', 'done': True, 'done_reason': 'length', 'total_duration': 153149916750, 'load_duration': 88908708, 'prompt_eval_count': 352, 'prompt_eval_duration': 1017898041, 'eval_count': 4096, 'eval_duration': 150543399327, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd98a-5b9f-7952-89cd-39abacac7499-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 352, 'output_tokens': 4096, 'total_tokens': 4448}
# WMT83805: None
# LLM OUTPUT: content='' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:05:25.290225Z', 'done': True, 'done_reason': 'length', 'total_duration': 155301656875, 'load_duration': 104694333, 'prompt_eval_count': 328, 'prompt_eval_duration': 989818500, 'eval_count': 4096, 'eval_duration': 152736483327, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd98c-b303-7592-b03f-d5dea47ad379-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 328, 'output_tokens': 4096, 'total_tokens': 4424}
# YP_009790355: None
# LLM OUTPUT: content='{"thermal_range": "psychrophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:06:56.152673Z', 'done': True, 'done_reason': 'stop', 'total_duration': 90210465459, 'load_duration': 103818792, 'prompt_eval_count': 363, 'prompt_eval_duration': 1077524584, 'eval_count': 2362, 'eval_duration': 88215472221, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd98f-1434-7233-a113-9b63e14db884-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 363, 'output_tokens': 2362, 'total_tokens': 2725}
# YP_006489335: psychrophile
# LLM OUTPUT: content='{"thermal_range": "mesophile"}' additional_kwargs={} response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-29T14:08:58.288158Z', 'done': True, 'done_reason': 'stop', 'total_duration': 121476892125, 'load_duration': 100862583, 'prompt_eval_count': 378, 'prompt_eval_duration': 1092706375, 'eval_count': 3173, 'eval_duration': 119174001504, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'} id='lc_run--019dd990-7729-7221-9116-451fdaed006c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 378, 'output_tokens': 3173, 'total_tokens': 3551}
# YP_009209738: mesophile
