# %%
############################################################################## MESOPHILES ################################################################################

e1={'Thermal Range': 'mesophile',
    'Accession': 'ADI87650'}

e2={'Thermal Range': 'mesophile',
    'Accession': 'WXH46553'}

e3={'Thermal Range': 'mesophile',
    'Accession': 'WRQ14408'}

e4={'Thermal Range': 'mesophile',
    'Accession': 'XYW65533'}

e5={'Thermal Range': 'mesophile',
    'Accession': 'SNQ28030'}

e6={'Thermal Range': 'mesophile',
    'Accession': 'NP_049775',}

e7={'Thermal Range': 'mesophile',
    'Accession': 'NP_049787'}

e8={'Thermal Range': 'mesophile',
    'Accession': 'YP_001956829'}

e9={'Thermal Range': 'mesophile',
    'Accession': 'AAC18470'}

e10={'Thermal Range': 'mesophile',
    'Accession': 'NP_046847'}

e11={'Thermal Range': 'mesophile',
    'Accession': 'NP_040628'}

e12={'Thermal Range': 'mesophile',
    'Accession': 'NP_040587'}

e13={'Thermal Range': 'mesophile',
    'Accession': 'NP_042001'}

e14={'Thermal Range': 'mesophile',
    'Accession': 'NP_042005'}

e15={'Thermal Range': 'mesophile',
    'Accession': 'NP_041967'}

e16={'Thermal Range': 'mesophile',
    'Accession': 'NP_049666'}

e17={'Thermal Range': 'mesophile',
    'Accession': 'YP_010085862'}

e18={'Thermal Range': 'mesophile',
    'Accession': 'YP_009168084'}

e19={'Thermal Range': 'mesophile',
    'Accession': 'YP_001956832'}

e20={'Thermal Range': 'mesophile',
    'Accession': 'YP_001956835'}


############################################################################## THERMOPHILES ################################################################################

e21={'Thermal Range': 'thermophile',
    'Accession': 'A7XXB7'}

e22={'Thermal Range': 'thermophile',
    'Accession': 'QAY18187'}

e23={'Thermal Range': 'thermophile',
    'Accession': 'YP_001285867'}

e24={'Thermal Range': 'thermophile',
    'Accession': 'NP_835731'}

e25={'Thermal Range': 'thermophile',
    'Accession': 'YP_874174'} # very little on ncbi about this protein, interesting to see the results. No proteins so may not be able to get accessions. Potentiall replace

e26={'Thermal Range': 'thermophile',
     'Accession': 'YP_001468074'}

e27={'Thermal Range': 'thermophile',
     'Accession': 'YP_001468079'}

e28={'Thermal Range': 'thermophile',
     'Accession': 'YP_001468077'}

e29={'Thermal Range': 'thermophile',
     'Accession': 'YP_001468072'}

e30={'Thermal Range': 'thermophile',
     'Accession': 'YP_001285862'}

e31={'Thermal Range': 'thermophile',
     'Accession': 'BFP65619'}

e32={'Thermal Range': 'thermophile',
     'Accession': 'YP_001285822'}

e33={'Thermal Range': 'thermophile',
     'Accession': 'ABI36835'}

e34={'Thermal Range': 'thermophile',
     'Accession': 'NP_835728'}

e35={'Thermal Range': 'thermophile',
     'Accession': 'NP_835725'}

e36={'Thermal Range': 'thermophile',
     'Accession': 'YP_001210360'}

e37={'Thermal Range': 'thermophile',
     'Accession': 'YP_015542'}

e38={'Thermal Range': 'thermophile',
     'Accession': 'YP_001468067'}

e39={'Thermal Range': 'thermophile',
     'Accession': 'YP_009509140'}

e40={'Thermal Range': 'thermophile',
     'Accession': 'YP_009509134'}

############################################################################## PSYCHROPHILES ###############################################################################

e41={'Thermal Range': 'psychrophile',
    'Accession': 'XJP07760'}

e42={'Thermal Range': 'psychrophile',
    'Accession': 'WMT83805'}

e43={'Thermal Range': 'psychrophile',
    'Accession': 'YP_009790355'} # potentially replace this with better example, this is a sewage isolate

e44={'Thermal Range': 'psychrophile',
    'Accession': 'YP_006489335'} # only has hypothetical proteins, will be interesting to see

e45={'Thermal Range': 'psychrophile',
    'Accession': 'YP_009209738',
}

e46={'Thermal Range': 'psychrophile',
     'Accession': 'WMT83702'}

e47={'Thermal Range': 'psychrophile',
     'Accession': 'WMT83700'}

e48={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009790354'}

e49={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009790351'}

e50={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009790347'}

e51={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009790336'}

e52={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009008887'}

e53={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009008883'}

e54={'Thermal Range': 'psychrophile',
     'Accession': 'YP_009008872'}

e55={'Thermal Range': 'psychrophile',
     'Accession': 'YP_006489330'}

e56={'Thermal Range': 'psychrophile',
     'Accession': 'YP_006489329'}

e57={'Thermal Range': 'psychrophile',
     'Accession': 'YP_006489332'}

e58={'Thermal Range': 'psychrophile',
     'Accession': 'YP_112541'}

e59={'Thermal Range': 'psychrophile',
     'Accession': 'YP_010108907'}

e60={'Thermal Range': 'psychrophile',
     'Accession': 'YP_010108902'}

# %%
import pandas as pd


data = [e1, e2, e3, e4, e5, e6, e7, e8, e9, e10,
    e11, e12, e13, e14, e15, e16, e17, e18, e19, e20,
    e21, e22, e23, e24, e25, e26, e27, e28, e29, e30,
    e31, e32, e33, e34, e35, e36, e37, e38, e39, e40,
    e41, e42, e43, e44, e45, e46, e47, e48, e49, e50,
    e51, e52, e53, e54, e55, e56, e57, e58, e59, e60]

df=pd.DataFrame(data)
df.to_csv('data/example/example_data.csv', index=False)

# %%
df
# Out:
#    Thermal Range     Accession
# 0      mesophile      ADI87650
# 1      mesophile      WXH46553
# 2      mesophile      WRQ14408
# 3      mesophile      XYW65533
# 4      mesophile      SNQ28030
# 5      mesophile     NP_049775
# 6      mesophile     NP_049787
# 7      mesophile  YP_001956829
# 8      mesophile      AAC18470
# 9      mesophile     NP_046847
# 10     mesophile     NP_040628
# 11     mesophile     NP_040587
# 12     mesophile     NP_042001
# 13     mesophile     NP_042005
# 14     mesophile     NP_041967
# 15     mesophile     NP_049666
# 16     mesophile  YP_010085862
# 17     mesophile  YP_009168084
# 18     mesophile  YP_001956832
# 19     mesophile  YP_001956835
# 20   thermophile        A7XXB7
# 21   thermophile      QAY18187
# 22   thermophile  YP_001285867
# 23   thermophile     NP_835731
# 24   thermophile     YP_874174
# 25   thermophile  YP_001468074
# 26   thermophile  YP_001468079
# 27   thermophile  YP_001468077
# 28   thermophile  YP_001468072
# ...
